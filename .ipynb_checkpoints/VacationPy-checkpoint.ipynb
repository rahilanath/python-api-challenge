# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Input File (CSV)
input_data_file = 'output_data/clean_cities.csv'

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
clean_city_df = pd.read_csv(input_data_file)
clean_city_df
# Out:
#                City     Lat    Lng  Max Temp  Humidity  Wind Speed  \
# 0           Iqaluit  -68.51  63.75     55.40        87       16.11
# 1             Kapaa -159.32  22.08     82.40        74       10.29
# 2    Saint-Philippe   55.77 -21.36     62.60        63        6.93
# 3           Rikitea -134.97 -23.12     70.68        74        9.80
# 4       San Quintín -115.95  30.48     70.43        68       19.19
# ..              ...     ...    ...       ...       ...         ...
# 554        Kawakawa  174.07 -35.38     63.00         3        7.00
# 555          Vuktyl   57.31  63.86     59.86        82        9.08
# 556        Kayerkan   87.76  69.35     57.20        82        4.47
# 557    Khudumelapye   24.75 -23.88     52.18        38        6.13
# 558        Djibouti   42.50  11.50     89.60        62        3.36
#
#      Cloudiness Country        Date
# 0            90      CA  1596674195
# 1            90      US  1596674195
# 2            40      RE  1596673953
# 3            17      PF  1596673958
# 4             0      MX  1596674197
# ..          ...     ...         ...
# 554         100      NZ  1596674408
# 555          92      RU  1596674409
# 556           0      RU  1596674409
# 557           0      BW  1596674409
# 558          75      DJ  1596674410
#
# [559 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
long_lat = clean_city_df[['Lng','Lat']]
coordinates = long_lat.to_records(index=False)
humidity = clean_city_df['Humidity']

med_long = clean_city_df['Lng'].median()
med_lat = clean_city_df['Lat'].median()
max_humid = clean_city_df['Humidity'].max()

figure_layout = {
    'width': '650px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
    }

gmaps.configure(api_key=g_key)
fig = gmaps.figure(layout=figure_layout, center=(med_long,med_lat),
                   zoom_level=1.5, display_toolbar=False)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %%
heat_layer = gmaps.heatmap_layer(locations=coordinates, weights=humidity, 
                                 dissipating=False, max_intensity=max_humid,
                                 point_radius=1)

fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
ideal_temps_rng = np.arange(60, 77, 1)
ideal_humid_rng = np.arange(60, 70, 1)
ideal_wind_speed_rng = np.arange(2, 7, 1)

not_ideal_weather_df = clean_city_df.loc[(~clean_city_df['Max Temp'].isin(ideal_temps_rng)) &
                                         (~clean_city_df['Humidity'].isin(ideal_humid_rng)) &
                                         (~clean_city_df['Wind Speed'].isin(ideal_wind_speed_rng))]

ideal_weather_cities = (clean_city_df.drop(index=not_ideal_weather_df.index)).dropna().reset_index(drop=True)
ideal_weather_cities
# Out:
#                   City     Lat    Lng  Max Temp  Humidity  Wind Speed  \
# 0       Saint-Philippe   55.77 -21.36     62.60        63        6.93
# 1          San Quintín -115.95  30.48     70.43        68       19.19
# 2                  Eyl   49.82   7.98     79.03        63       23.35
# 3         Port Lincoln  135.87 -34.73     51.39        63       20.69
# 4          Provideniya -173.30  64.38     55.40        66       13.42
# ..                 ...     ...    ...       ...       ...         ...
# 116    Serebryanyy Bor  124.80  56.80     70.00        49        2.06
# 117  City of San Pedro  121.02  14.35     87.01        72        4.00
# 118       Constitución  -72.42 -35.33     48.96        67        8.99
# 119           Kawakawa  174.07 -35.38     63.00         3        7.00
# 120           Djibouti   42.50  11.50     89.60        62        3.36
#
#      Cloudiness Country        Date
# 0            40      RE  1596673953
# 1             0      MX  1596674197
# 2            96      SO  1596674198
# 3           100      AU  1596674129
# 4            75      RU  1596674200
# ..          ...     ...         ...
# 116           7      RU  1596674405
# 117          99      PH  1596674406
# 118           0      CL  1596674407
# 119         100      NZ  1596674408
# 120          75      DJ  1596674410
#
# [121 rows x 9 columns]

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = ideal_weather_cities
hotel_df['Hotel Name'] = ''
hotel_df
# Out:
#                   City     Lat    Lng  Max Temp  Humidity  Wind Speed  \
# 0       Saint-Philippe   55.77 -21.36     62.60        63        6.93
# 1          San Quintín -115.95  30.48     70.43        68       19.19
# 2                  Eyl   49.82   7.98     79.03        63       23.35
# 3         Port Lincoln  135.87 -34.73     51.39        63       20.69
# 4          Provideniya -173.30  64.38     55.40        66       13.42
# ..                 ...     ...    ...       ...       ...         ...
# 116    Serebryanyy Bor  124.80  56.80     70.00        49        2.06
# 117  City of San Pedro  121.02  14.35     87.01        72        4.00
# 118       Constitución  -72.42 -35.33     48.96        67        8.99
# 119           Kawakawa  174.07 -35.38     63.00         3        7.00
# 120           Djibouti   42.50  11.50     89.60        62        3.36
#
#      Cloudiness Country        Date Hotel Name
# 0            40      RE  1596673953
# 1             0      MX  1596674197
# 2            96      SO  1596674198
# 3           100      AU  1596674129
# 4            75      RU  1596674200
# ..          ...     ...         ...        ...
# 116           7      RU  1596674405
# 117          99      PH  1596674406
# 118           0      CL  1596674407
# 119         100      NZ  1596674408
# 120          75      DJ  1596674410
#
# [121 rows x 10 columns]

# %%
city_coord = hotel_df[['Lng','Lat']]

for city in city_coord:
    # geocoordinates
    target_coordinates = f'{city_coord.iloc[0,0]},{city_coord.iloc[0,1]}'
    target_radius = 5000
    target_type = "hotel"
    
    # set up a parameters dictionary
    params = {
        'location': target_coordinates,
        'radius': target_radius,
        'type': target_type,
        'key': g_key
    }

# # base url
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# # run a request using our params dictionary
# response = requests.get(base_url, params=params)
# response.json()

#     find_hotels = requests.get(base_google_url, params).json()
#     print(find_hotels)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCGgEAALnFXUyCYcYzUI0TcJfztHXCBq8m14gmGR4toapGPp5FCR8KnNgZHoOldbKZlvNxmgzSmJUw1z73OYGOv02_newkKngy4i1uIvO8lfsgmqEG7mRTdATGP3K-NXJ-IrvJTfnCpuWH6GmOPq-wFt79RUgLi1TVPP9nZO1riuRkrvpal_AIN4H516hv-EIAmDB_SpepU5cNuzlJR8tB81wBGxCEsrgoNtQDAp5Zc-p9A5RTtmKlOFkSe0a4wT_bwbR0BRncKI8ksmtrhTKW1SqIvQPEuczKECcLTHRxEfRzd9wfFed4RxjwUlJpARoqHXms9mVu7c71_W19CrUNHWYAtP9dqB56WSKG9SNkxCxvsYrZJN3JtUvyNkfvnRP5KJq2WhIQ6U0lvQX3FAjtP5ujLyJS2hoUo5gmAuZ9Tt4IRWWGHIiuIUnxRZA',
#  'results': [{'geometry': {'location': {'lat': -21.358118, 'lng': 55.764656},
#     'viewport': {'northeast': {'lat': -21.3477259, 'lng': 55.78066339999999},
#      'southwest': {'lat': -21.3685093, 'lng': 55.7486486}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png',
#    'name': 'Saint-Philippe',
#    'photos': [{'height': 1528,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111478921469695467007">Brasva S.</a>'],
#      'photo_reference': 'CmRaAAAAP-pV7iT_3KuuoqleKxMaXrUaQgKzTRdH5fUbEzF2qSG4c1mMGvqEAL1UMIxvtW7NHXsr1_7hfBYHnvMcfcUwczUrxx48Kwmkms6IpzVMc8ooWo1rJuk9A0JgOmlECg0kEhA4ZzcwRD_nb_fmmKzjzj4BGhSlm18-ockvBHmsIIWqWFoYwAIDiQ',
#      'width': 2296}],
#    'place_id': 'ChIJZ4E36psUeCERfB6DO9-JjTY',
#    'reference': 'ChIJZ4E36psUeCERfB6DO9-JjTY',
#    'scope': 'GOOGLE',
#    'types': ['locality', 'political'],
#    'vicinity': 'Saint-Philippe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.358434, 'lng': 55.77032209999999},
#     'viewport': {'northeast': {'lat': -21.3570810697085,
#       'lng': 55.7717046302915},
#      'southwest': {'lat': -21.3597790302915, 'lng': 55.7690066697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': '4d0a3830f155b37ecf3eb2a519dd3a863498054e',
#    'name': 'Chambres d\'hôte "La Trinité"',
#    'photos': [{'height': 366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117069031951999342120">Chambres d&#39;hôte &quot;La Trinité&quot;</a>'],
#      'photo_reference': 'CmRaAAAA2U_w_KMtWsjArzJO0mgqj5-DtfMMiZQSWol11vQLVaY6iZssJTIv11vdd8R309O8wbrKodAh75ju9HXgJYlO3NPZ6H5mafAmiEAaPLtDFCl6lFX9GaQkNRUNjM67q-CjEhBHwfmt9wDraxhqzSrEgYFmGhTxpcn06Q-UE26frj3z1f4PoUvjAg',
#      'width': 550}],
#    'place_id': 'ChIJqSF_M5cUeCERuCMQ4H3g9oM',
#    'plus_code': {'compound_code': 'JQRC+J4 Saint-Philippe, Réunion',
#     'global_code': '5HCQJQRC+J4'},
#    'rating': 3.5,
#    'reference': 'ChIJqSF_M5cUeCERuCMQ4H3g9oM',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 11,
#    'vicinity': '12 Rue De La Pompe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.360383, 'lng': 55.766676},
#     'viewport': {'northeast': {'lat': -21.3590231197085,
#       'lng': 55.7680625802915},
#      'southwest': {'lat': -21.3617210802915, 'lng': 55.7653646197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'name': 'SUNLIGHT FM',
#    'place_id': 'ChIJtVdz-ZoUeCERU7-fqi0SqOQ',
#    'plus_code': {'compound_code': 'JQQ8+RM Saint-Philippe, Réunion',
#     'global_code': '5HCQJQQ8+RM'},
#    'rating': 4.3,
#    'reference': 'ChIJtVdz-ZoUeCERU7-fqi0SqOQ',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 3,
#    'vicinity': '4 Rue de la Marine, Saint-Philippe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3599362, 'lng': 55.76721879999999},
#     'viewport': {'northeast': {'lat': -21.3587151697085,
#       'lng': 55.7686115302915},
#      'southwest': {'lat': -21.36141313029151, 'lng': 55.7659135697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/movies-71.png',
#    'id': '556eced4d630f60f200932e68290cf947cde5044',
#    'name': 'Cinéma Henri Madoré',
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102741127495531900220">L&#39;Eden restaurant Traiteur</a>'],
#      'photo_reference': 'CmRZAAAA7jwdHj4tz7zmkZtdtIxLNvyno0lO8u0BecfIyS1qCLNE-94bDPbBuG_hes0cCjv7tOLZ-Ub76MDP57DhKWzMnoDV2A7wEx_n7Qgk7H39LRx09YFV2aVv4sadbmNqMyCQEhAmPVGhBwdHRtyJ_R6G-VnoGhSFsBOU8Sd99jtvfg7JaSMQ2_ygyQ',
#      'width': 3096}],
#    'place_id': 'ChIJI7-e75oUeCERkEWvlxIbSqg',
#    'plus_code': {'compound_code': 'JQR8+2V Saint-Philippe, Réunion',
#     'global_code': '5HCQJQR8+2V'},
#    'rating': 3.4,
#    'reference': 'ChIJI7-e75oUeCERkEWvlxIbSqg',
#    'scope': 'GOOGLE',
#    'types': ['movie_theater', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': '1 Rue du Stade'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3594456, 'lng': 55.7665063},
#     'viewport': {'northeast': {'lat': -21.3581231197085,
#       'lng': 55.7678678302915},
#      'southwest': {'lat': -21.3608210802915, 'lng': 55.7651698697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '915f1a9a570c82d5226b28eff9e4ca3216562c54',
#    'name': 'Office de Tourisme de Saint-Philippe',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105242833804521285861">Fab974 Lagaite</a>'],
#      'photo_reference': 'CmRaAAAAdJm8qQOUhX1427VpjwWdWiSoD9W8QPT5zHjpHP1dOxykDRZNRZpSEdBuu-6s00BjOytyil_kwFZ-dds87-DZC4DlDuKjRh9xUeJr4fqKmyVj5Q6H9GXeWXxvmfhgMQetEhApF9swbZQ4tDYAgGFK2IAPGhRw07IESvcAsbLj1mfeosxfoSe8Eg',
#      'width': 5312}],
#    'place_id': 'ChIJM99_QZoUeCERhlmoGTyor4g',
#    'plus_code': {'compound_code': 'JQR8+6J Saint-Philippe, Réunion',
#     'global_code': '5HCQJQR8+6J'},
#    'rating': 3.7,
#    'reference': 'ChIJM99_QZoUeCERhlmoGTyor4g',
#    'scope': 'GOOGLE',
#    'types': ['travel_agency', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 7,
#    'vicinity': '41A Rue Leconte de Lisle, Saint Pierre'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.359839, 'lng': 55.765989},
#     'viewport': {'northeast': {'lat': -21.3584443697085,
#       'lng': 55.7673149802915},
#      'southwest': {'lat': -21.3611423302915, 'lng': 55.7646170197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/gas_station-71.png',
#    'name': 'Station-service Total Saint Philippe',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2322,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114555693622043823734">Station-service Total Saint Philippe</a>'],
#      'photo_reference': 'CmRaAAAAexedHLKvrB4IFtp7RQD87nct6vDPbK2ZnAaiaikTU95ebBHxsbF-GcvOOPcBJM73wXvjCXN72s7cCDl1PF0wpuSa2lOM_OizE0BnugUriPjVIKkO2oSDglBba38k4rNPEhBqU8458bqWngIO_1LyAt9sGhTkTjzdeZ72lkc3-0XGnojjngGlkw',
#      'width': 4128}],
#    'place_id': 'ChIJeZpWqpsUeCERndQPUAfuUkM',
#    'plus_code': {'compound_code': 'JQR8+39 Saint-Philippe, Réunion',
#     'global_code': '5HCQJQR8+39'},
#    'rating': 4.1,
#    'reference': 'ChIJeZpWqpsUeCERndQPUAfuUkM',
#    'scope': 'GOOGLE',
#    'types': ['gas_station', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 15,
#    'vicinity': '54 Rue Leconte de Lisle'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3640239, 'lng': 55.7428052},
#     'viewport': {'northeast': {'lat': -21.3628490197085,
#       'lng': 55.7441605302915},
#      'southwest': {'lat': -21.3655469802915, 'lng': 55.7414625697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_recreational-71.png',
#    'name': 'Parfums et Épices Garden',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3464,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102250055258404375460">Cédric WEMMERT</a>'],
#      'photo_reference': 'CmRaAAAAYnZrZ__mOs4T3sbwaJcf5RISHHaOcQZG7V3Ue_TZbQI-zSz_Dqswhuu1GkG0tZ8GJ6OKrqcm8jE92r6MhYiHJnUhCwJ_TcltLG6bokHY3nKJydY7OTDuUQA-Rgj5X1HEEhDrY7FYZtuJ0pIu-yKX9sGUGhRB3N7zcR8n6CHWazwQlZxnc0nxGg',
#      'width': 4618}],
#    'place_id': 'ChIJGTUrMEUqzBIRiJBBOVLROFE',
#    'plus_code': {'compound_code': 'JPPV+94 Saint-Philippe, Réunion',
#     'global_code': '5HCQJPPV+94'},
#    'rating': 4.4,
#    'reference': 'ChIJGTUrMEUqzBIRiJBBOVLROFE',
#    'scope': 'GOOGLE',
#    'types': ['tourist_attraction',
#     'grocery_or_supermarket',
#     'park',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 942,
#    'vicinity': '7 Chemin Forestier'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3681875, 'lng': 55.7375962},
#     'viewport': {'northeast': {'lat': -21.3668398697085,
#       'lng': 55.7389046802915},
#      'southwest': {'lat': -21.3695378302915, 'lng': 55.7362067197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'b52467a2eeb261b4a2f805618f14eb77bf414cf8',
#    'name': 'BM FROID CLIMAT',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100005594467968968699">BM FROID CLIMAT</a>'],
#      'photo_reference': 'CmRaAAAAUTEVOaQo_GusPZRWse8IN6HzfmyInibWGIq61mFBLl87UWD_EupuGT3E4mdnHGrsfQ2K-nxvufIOSVeGhuIacmMat0u4JyWLQVsnIArvCPQOqq2qgNFy0VEDIhf1yRUKEhB8XSa7jWzzMVM2sPN7dlk8GhQBLmQwTsFu4xqYW5Kn8gYM2Fwanw',
#      'width': 4032}],
#    'place_id': 'ChIJI4mLs58TeCERHS30RuZlAqo',
#    'plus_code': {'compound_code': 'JPJQ+P2 Saint-Philippe, Réunion',
#     'global_code': '5HCQJPJQ+P2'},
#    'rating': 5,
#    'reference': 'ChIJI4mLs58TeCERHS30RuZlAqo',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Saint-Philippe, 111 Rn2 le baril'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3691889, 'lng': 55.7321806},
#     'viewport': {'northeast': {'lat': -21.3677904697085,
#       'lng': 55.7335201302915},
#      'southwest': {'lat': -21.3704884302915, 'lng': 55.7308221697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'name': 'Le Ti Vacoa',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4128,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114985416650253326343">Didier ROSE</a>'],
#      'photo_reference': 'CmRaAAAAvxp_l9QPJBoC7Hq3-Xau8awTF0gIlkyc_s0VuR_JBXkOc696niBALJqvBLTVApF2Dw7Wv_rklSAAPwXJQJX3R1jcJ1J9HUp31Awwp_i7d7su_Q34c5xRnjGM3hUdecVpEhB0Vq3RnLo2nGYihpSvoFd6GhTRmng7YIoljI1pmgre3yw1F2YTjg',
#      'width': 3096}],
#    'place_id': 'ChIJ9bKacqETeCER6BnmSLXCs7w',
#    'plus_code': {'compound_code': 'JPJJ+8V Saint-Philippe, Réunion',
#     'global_code': '5HCQJPJJ+8V'},
#    'rating': 3.5,
#    'reference': 'ChIJ9bKacqETeCER6BnmSLXCs7w',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 18,
#    'vicinity': 'Saint-Philippe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.36910659999999, 'lng': 55.727522},
#     'viewport': {'northeast': {'lat': -21.3677345697085,
#       'lng': 55.7288677802915},
#      'southwest': {'lat': -21.3704325302915, 'lng': 55.7261698197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'id': 'c2505c23b8aba5daba27331890210ef66ed1af90',
#    'name': 'Le four à pain',
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110503838680164142888">Stéphanie Ah</a>'],
#      'photo_reference': 'CmRaAAAAGlo-4yIOFkB8nYf0lCZMCQYMVcmDVaBfT_vwFlGB91Ca18qsBzNwYy7i9TEq9tLO3SmgD6_i8MPkERm2lNRuZtif_EmYIgsr1kf8Iba9j36KvufYpH4zVP5sldjAvBdREhD5DVHSY4boxJgyuMloMPpeGhQVWxdIuyGLpzVKPAW2g3uli9ulkQ',
#      'width': 4032}],
#    'place_id': 'ChIJuWs3ZQJreCER5e7xKFgaz8c',
#    'plus_code': {'compound_code': 'JPJH+92 Saint-Philippe, Réunion',
#     'global_code': '5HCQJPJH+92'},
#    'rating': 4.9,
#    'reference': 'ChIJuWs3ZQJreCER5e7xKFgaz8c',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 18,
#    'vicinity': '63C RN2 Le Baril, Saint-Philippe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3691422, 'lng': 55.72571829999999},
#     'viewport': {'northeast': {'lat': -21.3678880197085,
#       'lng': 55.72708063029149},
#      'southwest': {'lat': -21.3705859802915, 'lng': 55.72438266970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#    'id': '57faa5f573f952a2642bed75397301f278cc96e7',
#    'name': 'Le 57',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3096,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113403816063148713867">Didier Rose</a>'],
#      'photo_reference': 'CmRaAAAAtTg0KhjexXLqnLpLK2aucBQH3Cjc7N7FPEeL3Z3KJxChcuckcwQ7gt9WHMCEEL0fH7F0b_Gtpfp98mIkme0hD0f56iP0wTySHivlG7HIsEW6EmIiFY3qHht4f8ozyE1PEhDmi23jI5BP5H3ESvuirOGYGhRGrzyt4hzQYBO1Vg6Y7V4oy6PLJg',
#      'width': 4128}],
#    'place_id': 'ChIJ99_U5qUTeCER93aFo97klFk',
#    'plus_code': {'compound_code': 'JPJG+87 Matouta, Réunion',
#     'global_code': '5HCQJPJG+87'},
#    'rating': 3.8,
#    'reference': 'ChIJ99_U5qUTeCER93aFo97klFk',
#    'scope': 'GOOGLE',
#    'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 32,
#    'vicinity': '57 Route Nationale 2 Baril'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3258227, 'lng': 55.7999575},
#     'viewport': {'northeast': {'lat': -21.3244749197085,
#       'lng': 55.8014724302915},
#      'southwest': {'lat': -21.32717288029151, 'lng': 55.7987744697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Le Crabe Sous la Varangue',
#    'photos': [{'height': 1371,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103054653535960369562">Martin Roth</a>'],
#      'photo_reference': 'CmRaAAAAoCpb02XJg3QCQBst5KVrzvALyDgHUeETOvtIqlgcYNCpIGUwnnc8mrl3eYTbyyZ-uLRcnKdmOGu9BMdd18wCbghFPSJMbIVPc4_kIJH6t38L42BbVIPeqqWFqf5Jpx7zEhCLbyt2Tlx1SPFqSW2ppyXAGhTfH8EAwlIe9FVHhQYb9I3MM4Ce4g',
#      'width': 2048}],
#    'place_id': 'ChIJ71oWBCdreCER9J1crievLuk',
#    'plus_code': {'compound_code': 'MQFX+MX Saint-Philippe, Réunion',
#     'global_code': '5HCQMQFX+MX'},
#    'rating': 4.8,
#    'reference': 'ChIJ71oWBCdreCER9J1crievLuk',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 17,
#    'vicinity': '1 Route Nationale 2 le Tremblet'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.325001, 'lng': 55.79986},
#     'viewport': {'northeast': {'lat': -21.32361211970849,
#       'lng': 55.80136668029149},
#      'southwest': {'lat': -21.3263100802915, 'lng': 55.79866871970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': 'f6cf34ce40350f7b60dc1e3c5ded0cc550007e4a',
#    'name': 'Blue Escale - Vanilla Workshop',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 620,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100750955466649376665">Escale Bleue - Atelier Vanille</a>'],
#      'photo_reference': 'CmRaAAAAyRSUXZxiKWgKOGk_ssiNpl_Rpp7NiLBOCe9jUJueL_cc2xuLZYNR8YK8k3d1d0MNDTe1eBzyXLTf8jnJpATMX-wv05mLlyWfqiVDDdy9RcV_Tj5F8h1MYnUhwSOlgxpfEhCmsxd-xC-sqVqawcbCqibdGhSD4efq7-YXXbYswxNid6KNU5oTCw',
#      'width': 1037}],
#    'place_id': 'ChIJtdvoLCdreCERD2IhphEVR_E',
#    'plus_code': {'compound_code': 'MQFX+XW Saint-Philippe, Réunion',
#     'global_code': '5HCQMQFX+XW'},
#    'rating': 4.4,
#    'reference': 'ChIJtdvoLCdreCERD2IhphEVR_E',
#    'scope': 'GOOGLE',
#    'types': ['tourist_attraction',
#     'food',
#     'point_of_interest',
#     'store',
#     'establishment'],
#    'user_ratings_total': 317,
#    'vicinity': 'Route Nationale 2 le Tremblet, Saint-Philippe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3590913, 'lng': 55.7705253},
#     'viewport': {'northeast': {'lat': -21.3577401197085,
#       'lng': 55.7718891802915},
#      'southwest': {'lat': -21.3604380802915, 'lng': 55.7691912197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Le Palmier',
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115962503731463357701">Pat C</a>'],
#      'photo_reference': 'CmRaAAAAUTBkKcjDakxst_x-TChmbpsqmmipaH6zl2V3pm48yG7zTu8_AZAXGZRTXclIuKdl4xxmGYiOh6FkP_QD2s8fnwMB_YrSpYvHxlxjBIjNXszmuRiyRUwZIUqfqPSeo9IWEhCYDdWkwkjgMlIC65jD3aZTGhS5hfnk1-_7noYh4fs8Qzjls5w6cA',
#      'width': 3984}],
#    'place_id': 'ChIJ8WorxpAUeCERMgx_wAiW31s',
#    'plus_code': {'compound_code': 'JQRC+96 Saint-Philippe, Réunion',
#     'global_code': '5HCQJQRC+96'},
#    'rating': 4.1,
#    'reference': 'ChIJ8WorxpAUeCERMgx_wAiW31s',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 10,
#    'vicinity': '8 Rue De La Pompe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3607971, 'lng': 55.77134789999999},
#     'viewport': {'northeast': {'lat': -21.35951051970849,
#       'lng': 55.7725251302915},
#      'southwest': {'lat': -21.3622084802915, 'lng': 55.7698271697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'name': 'Ferme Equestre du Sud Sauvage',
#    'place_id': 'ChIJXfCiG24VeCERLqrwsYCDhAw',
#    'plus_code': {'compound_code': 'JQQC+MG Saint-Philippe, Réunion',
#     'global_code': '5HCQJQQC+MG'},
#    'reference': 'ChIJXfCiG24VeCERLqrwsYCDhAw',
#    'scope': 'GOOGLE',
#    'types': ['point_of_interest', 'establishment'],
#    'vicinity': '4 Rue De La Pompe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.36032849999999, 'lng': 55.7683099},
#     'viewport': {'northeast': {'lat': -21.35902661970849,
#       'lng': 55.7694378802915},
#      'southwest': {'lat': -21.3617245802915, 'lng': 55.7667399197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/stadium-71.png',
#    'name': 'Stade Mandanne Turpin',
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105242833804521285861">Fab974 Lagaite</a>'],
#      'photo_reference': 'CmRaAAAA2NOrFnM05sKmEvTBp5zENEeNsFMXiOjxkXnc5-TN3DcwAwPzrQfZzMjfq3DRXhEzQCggVfO2Jy-43wB26HYvMvXfxUz5whl1FvhhXYtzvYeAoVT2a38qOyy1CvY3hBdoEhDVkjdW3uwy_4ywNV7Fqe4lGhSPFKoh909c_BmsxMPxIaet8ewPYA',
#      'width': 5312}],
#    'place_id': 'ChIJyxfafJoUeCERGnsRICBNhNg',
#    'plus_code': {'compound_code': 'JQQ9+V8 Saint-Philippe, Réunion',
#     'global_code': '5HCQJQQ9+V8'},
#    'rating': 3,
#    'reference': 'ChIJyxfafJoUeCERGnsRICBNhNg',
#    'scope': 'GOOGLE',
#    'types': ['stadium', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': '2-42 Rue du Stade'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3586271, 'lng': 55.7685536},
#     'viewport': {'northeast': {'lat': -21.35730466970849,
#       'lng': 55.76992078029149},
#      'southwest': {'lat': -21.3600026302915, 'lng': 55.76722281970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/bank_dollar-71.png',
#    'name': 'Crédit Agricole Réunion - Mayotte | Distributeur de billets',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 481,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118198935808146478097">Crédit Agricole Réunion - Mayotte | Distributeur de billets</a>'],
#      'photo_reference': 'CmRaAAAAuCdTfMRnKy3YCpBkLgH3nIFgNsYYTIEpl1dL7853rPaoc7gIm4kZjjoaJQtsZ5zncR8YQZThgUAjQ1yw1Mh6rc2lmvZoglEC_YJxZnHOk3ksIw6cOrZkx_gWnglzJonxEhDQ6fTumLXgwt1lkjzrLFPKGhSm0m-HEqpTEamSrIholWJAtG_k9Q',
#      'width': 855}],
#    'place_id': 'ChIJWZcUBpoUeCERerNPOAJSJUg',
#    'plus_code': {'compound_code': 'JQR9+GC Saint-Philippe, Réunion',
#     'global_code': '5HCQJQR9+GC'},
#    'reference': 'ChIJWZcUBpoUeCERerNPOAJSJUg',
#    'scope': 'GOOGLE',
#    'types': ['bank', 'atm', 'finance', 'point_of_interest', 'establishment'],
#    'vicinity': '74-80 Rue Leconte de Lisle'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3581542, 'lng': 55.768862},
#     'viewport': {'northeast': {'lat': -21.35674796970849,
#       'lng': 55.7702772802915},
#      'southwest': {'lat': -21.3594459302915, 'lng': 55.7675793197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/worship_general-71.png',
#    'name': 'EGLISE SAINT PHILIPPE',
#    'photos': [{'height': 751,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106864248650833072754">Eric Filliat</a>'],
#      'photo_reference': 'CmRaAAAAfTjwQ1bNZhSaeLzQkVFFWRl_LMtxTAC-naMoJkel7V-E42Xah9mqILciracmgfxCt5iJPCbhnlBVOx-dswxGERT-6OA9Z9Fm_tevDnmWf_pjygooGYzB1w98jVBF3sruEhCGKqAX26kI2WOmsqumIOm-GhRgA_kss_Vqxjh26a7LmFJYCMxpVQ',
#      'width': 1001}],
#    'place_id': 'ChIJI5QvapoUeCERp6hSCvCRhvI',
#    'plus_code': {'compound_code': 'JQR9+PG Saint-Philippe, Réunion',
#     'global_code': '5HCQJQR9+PG'},
#    'rating': 4,
#    'reference': 'ChIJI5QvapoUeCERp6hSCvCRhvI',
#    'scope': 'GOOGLE',
#    'types': ['church',
#     'place_of_worship',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 6,
#    'vicinity': 'Rue Leconte de Lisle'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3612434, 'lng': 55.7681524},
#     'viewport': {'northeast': {'lat': -21.3599577697085,
#       'lng': 55.76952583029149},
#      'southwest': {'lat': -21.3626557302915, 'lng': 55.76682786970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png',
#    'id': '37fc5a4cd86b60fbed9cb513f8b310c94bd2b6bc',
#    'name': 'Gymnase de Saint-Philippe',
#    'place_id': 'ChIJKcvHj5oUeCERLIbLCY7hX74',
#    'plus_code': {'compound_code': 'JQQ9+G7 Saint-Philippe, Réunion',
#     'global_code': '5HCQJQQ9+G7'},
#    'rating': 4,
#    'reference': 'ChIJKcvHj5oUeCERLIbLCY7hX74',
#    'scope': 'GOOGLE',
#    'types': ['gym', 'health', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2,
#    'vicinity': 'Rue du College, Saint-Philippe'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': -21.3593725, 'lng': 55.7676751},
#     'viewport': {'northeast': {'lat': -21.3579103697085,
#       'lng': 55.76897298029149},
#      'southwest': {'lat': -21.3606083302915, 'lng': 55.7662750197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/civic_building-71.png',
#    'id': '11f4c0ff9eaedc50e6b4f616514a184c143ae616',
#    'name': 'Annexe de la region reunion',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113830823792613538480">Sfremi Kbidi</a>'],
#      'photo_reference': 'CmRaAAAAsE2rzL9KkKkPmVj25suF-VEBXC6kEUxdTfZSN4DwgRNvptihX8cBH1AxBh40Ymm8RUBQ1HnhyUVMKysahuKwef4ToIXFSaWFFzvrA6kXMC6gqr3HKitAUo9QCEZsxDd4EhC1FWPYqv93k_NqozJg51MBGhTHW5SO2ZclxsnruhJ_KeU7raRxyQ',
#      'width': 4032}],
#    'place_id': 'ChIJmSjzxGkVeCERurx7Qwt5a7w',
#    'plus_code': {'compound_code': 'JQR9+73 Saint-Philippe, Réunion',
#     'global_code': '5HCQJQR9+73'},
#    'rating': 5,
#    'reference': 'ChIJmSjzxGkVeCERurx7Qwt5a7w',
#    'scope': 'GOOGLE',
#    'types': ['local_government_office', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1,
#    'vicinity': '62 N2'}],
#  'status': 'OK'}

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
