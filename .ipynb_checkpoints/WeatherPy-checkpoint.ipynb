# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
# import time
# import itertools
import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = 'output_data/cities.csv'
output_clean_data_file = 'output_data/clean_cities.csv'

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
num_of_cities = len(cities)
print(num_of_cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#BLEH
city_datalist = []
record_count = 0
set_count = 1
not_found = 0

print(f'Beginning Data Retrieval\n-----------------------------')

#BLEH
for city in cities:
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    # bleh
    try:
        base_weather_url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&units=imperial&appid={weather_api_key}'
        city_data = requests.get(base_weather_url).json()
    
        city_def = {}
      
        city_def.update({'City': city_data['name'],
                         'Lat': city_data['coord']['lon'],
                         'Lng': city_data['coord']['lat'],
                         'Max Temp': city_data['main']['temp_max'],
                         'Humidity': city_data['main']['humidity'],
                         'Wind Speed': city_data['wind']['speed'],
                         'Cloudiness': city_data['clouds']['all'],
                         'Country': city_data['sys']['country'],
                         'Date': city_data['dt']})
        
        if record_count+1 < 50:
            city_datalist.append(city_def)
            record_count+=1
        else:
            city_datalist.append(city_def)
            record_count = 0
            set_count+=1
    
    except:
        print(f'City not found. Skipping...')
        not_found+=1
        pass
    
print(f'-----------------------------\nData Retrieval Complete\n-----------------------------')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 1 | iqaluit
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | san quintin
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | shelburne
# Processing Record 7 of Set 1 | victoria
# Processing Record 8 of Set 1 | eyl
# Processing Record 9 of Set 1 | bluff
# Processing Record 10 of Set 1 | port lincoln
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | saint george
# Processing Record 16 of Set 1 | sitka
# Processing Record 17 of Set 1 | nizhniy tsasuchey
# Processing Record 18 of Set 1 | hofn
# Processing Record 19 of Set 1 | barstow
# Processing Record 20 of Set 1 | hamilton
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 1 | dongsheng
# Processing Record 22 of Set 1 | qaqortoq
# Processing Record 23 of Set 1 | klaksvik
# Processing Record 24 of Set 1 | bobrovskiy
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | berbera
# Processing Record 28 of Set 1 | castro
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | ust-kuyga
# Processing Record 31 of Set 1 | torbay
# Processing Record 32 of Set 1 | aranos
# Processing Record 33 of Set 1 | burnie
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | miri
# Processing Record 37 of Set 1 | balkanabat
# Processing Record 38 of Set 1 | komsomolskiy
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 1 | pevek
# Processing Record 44 of Set 1 | margate
# Processing Record 45 of Set 1 | dingle
# Processing Record 46 of Set 1 | tandil
# Processing Record 47 of Set 1 | marawi
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | bogorodskoye
# Processing Record 0 of Set 2 | aksarka
# Processing Record 1 of Set 2 | dikson
# Processing Record 2 of Set 2 | mecca
# Processing Record 3 of Set 2 | nelson bay
# Processing Record 4 of Set 2 | ust-nera
# Processing Record 5 of Set 2 | cape coast
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | lasa
# Processing Record 9 of Set 2 | san angelo
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | sayyan
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | palmas
# Processing Record 16 of Set 2 | alberton
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | kentau
# Processing Record 19 of Set 2 | pervomayskoye
# Processing Record 20 of Set 2 | geraldton
# Processing Record 21 of Set 2 | chokurdakh
# Processing Record 22 of Set 2 | oriximina
# Processing Record 23 of Set 2 | georgetown
# Processing Record 24 of Set 2 | aklavik
# Processing Record 25 of Set 2 | ahipara
# Processing Record 26 of Set 2 | katsuura
# Processing Record 27 of Set 2 | tiksi
# Processing Record 28 of Set 2 | khatanga
# Processing Record 29 of Set 2 | doctor juan manuel frutos
# Processing Record 30 of Set 2 | bandarbeyla
# Processing Record 31 of Set 2 | axim
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | barrow
# Processing Record 34 of Set 2 
of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 4 | hobyo
# Processing Record 5 of Set 4 | udachnyy
# Processing Record 6 of Set 4 | nouadhibou
# Processing Record 7 of Set 4 | sechura
# Processing Record 8 of Set 4 | verkh-usugli
# Processing Record 9 of Set 4 | rovaniemi
# Processing Record 10 of Set 4 | bathsheba
# Processing Record 11 of Set 4 | chuy
# Processing Record 12 of Set 4 | esperance
# Processing Record 13 of Set 4 | choya
# Processing Record 14 of Set 4 | saint-georges
# Processing Record 15 of Set 4 | fuerte
# Processing Record 16 of Set 4 | navahrudak
# Processing Record 17 of Set 4 | sarany
# Processing Record 18 of Set 4 | dudinka
# Processing Record 19 of Set 4 | sabha
# Processing Record 20 of Set 4 | rapid valley
# Processing Record 21 of Set 4 | qaanaaq
# Processing Record 22 of Set 4 | borogontsy
# Processing Record 23 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 4 | batagay
# Processing Record 24 of Set 4 | magole
# Processing Record 25 of Set 4 | zhigansk
# Processing Record 26 of Set 4 | salalah
# Processing Record 27 of Set 4 | hilo
# Processing Record 28 of Set 4 | koulamoutou
# Processing Record 29 of Set 4 | kenai
# Processing Record 30 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 4 | chimore
# Processing Record 31 of Set 4 | kaihua
# Processing Record 32 of Set 4 | camacha
# Processing Record 33 of Set 4 | asmar
# Processing Record 34 of Set 4 | deputatskiy
# Processing Record 35 of Set 4 | majene
# Processing Record 36 of Set 4 | tura
# Processing Record 37 of Set 4 | nikolskoye
# Processing Record 38 of Set 4 | tual
# Processing Record 39 of Set 4 | zharkent
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 4 | magaria
# Processing Record 41 of Set 4 | maple creek
# Processing Record 42 of Set 4 | sabang
# Processing Record 43 of Set 4 | rio gallegos
# Processing Record 44 of Set 4 | periyanayakkanpalaiyam
# Processing Record 45 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 4 | banda aceh
# Processing Record 46 of Set 4 | severnoye
# Processing Record 47 of Set 4 | bredasdorp
# Processing Record 48 of Set 4 | necochea
# Processing Record 49 of Set 4 | vestmannaeyjar
# Processing Record 0 of Set 5 | pekan
# Processing Record 1 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 5 | isangel
# Processing Record 2 of Set 5 | port hedland
# Processing Record 3 of Set 5 | sulangan
# Processing Record 4 of Set 5 | la palma
# Processing Record 5 of Set 5 | madera
# Processing Record 6 of Set 5 | guerrero negro
# Processing Record 7 of Set 5 | airai
# Processing Record 8 of Set 5 | bonnyville
# Processing Record 9 of Set 5 | labuhan
# Processing Record 10 of Set 5 | cortez
# Processing Record 11 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 5 | bhinmal
# Processing Record 12 of Set 5 | nata
# Processing Record 13 of Set 5 | bethel
# Processing Record 14 of Set 5 | dutlwe
# Processing Record 15 of Set 5 | upornaya
# Processing Record 16 of Set 5 | cabo san lucas
# Processing Record 17 of Set 5 | kondinskoye
# Processing Record 18 of Set 5 | sao jose da coroa grande
# Processing Record 19 of Set 5 | san andres
# Processing Record 20 of Set 5 | oranjemund
# Processing Record 21 of Set 5 | bambous virieux
# Processing Record 22 of Set 5 | pinewood
# Processing Record 23 of Set 5 | jimma
# Processing Record 24 of Set 5 | salinopolis
# Processing Record 25 of Set 5 | thompson
# Processing Record 26 of Set 5 | havre-saint-pierre
# Processing Record 27 of Set 5 | jinan
# Processing Record 28 of Set 5 | matveyev kurgan
# Processing Record 29 of Set 5 | veraval
# Processing Record 30 of Set 5 | shelopugino
# Processing Record 31 of Set 5 | laurentides
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 5 | novo cruzeiro
# Processing Record 34 of Set 5 | elektrenai
# Processing Record 35 of Set 5 | qarchi gak
# Processing Record 36 of Set 5 | jarocin
# Processing Record 37 of Set 5 | zhangye
# Processing Record 38 of Set 5 | qui nhon
# Processing Record 39 of Set 5 | bambanglipuro
# Processing Record 40 of Set 5 | fortuna
# Processing Record 41 of Set 5 | la ronge
# Processing Record 42 of Set 5 | buchanan
# Processing Record 43 of Set 5 | yeppoon
# Processing Record 44 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 5 | vanimo
# Processing Record 45 of Set 5 | kashi
# Processing Record 46 of Set 5 | wattegama
# Processing Record 47 of Set 5 | lata
# Processing Record 48 of Set 5 | indramayu
# Processing Record 49 of Set 5 | litovko
# Processing Record 0 of Set 6 | zabaykalsk
# Processing Record 1 of Set 6 | arlit
# Processing Record 2 of Set 6 | ye
# City not found. Skipping...
# Processing Record 2 of Set 6 | hervey bay
# Processing Record 3 of Set 6 | nanortalik
# Processing Record 4 of Set 6 | ronne
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | camopi
# Processing Record 7 of Set 6 | luderitz
# Processing Record 8 of Set 6 | xingcheng
# Processing Record 9 of Set 6 | katha
# City not found. Skipping...
# Processing Record 9 of Set 6 | karratha
# Processing Record 10 of Set 6 | flin flon
# Processing Record 11 of Set 6 | faanui
# Processing Record 12 of Set 6 | jinchang
# Processing Record 13 of Set 6 | mount gambier
# Processing Record 14 of Set 6 | poum
# Processing Record 15 of Set 6 | fare
# Processing Record 16 of Set 6 | acacias
# Processing Record 17 of Set 6 | bol
# Processing Record 18 of Set 6 | bobrovka
# Processing Record 19 of Set 6 | souillac
# Processing Record 20 of Set 6 | lakes entrance
# Processing Record 21 of Set 6 | nanchang
# Processing Record 22 of Set 6 | otradnoye
# Processing Record 23 of Set 6 | college
# Processing Record 24 of Set 6 | omboue
# Processing Record 25 of Set 6 | hualmay
# Processing Record 26 of Set 6 | penzance
# Processing Record 27 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 6 | cabedelo
# Processing Record 28 of Set 6 | alofi
# Processing Record 29 of Set 6 | sokolo
# Processing Record 30 of Set 6 | corvallis
# Processing Record 31 of Set 6 | te anau
# Processing Record 32 of Set 6 | kamsack
# Processing Record 33 of Set 6 | fairview
# Processing Record 34 of Set 6 | elk plain
# Processing Record 35 of Set 6 | manokwari
# Processing Record 36 of Set 6 | kumluca
# Processing Record 37 of Set 6 | martinopolis
# Processing Record 38 of Set 6 | kjollefjord
# Processing Record 39 of Set 6 | ystad
# Processing Record 40 of Set 6 | altamira
# Processing Record 41 of Set 6 | sinnamary
# Processing Record 42 of Set 6 | kahului
# Processing Record 43 of Set 6 | saint anthony
# Processing Record 44 of Set 6 | alyangula
# Processing Record 45 of Set 6 | namatanai
# Processing Record 46 of Set 6 | rodino
# Processing Record 47 of Set 6 | olafsvik
# Processing Record 48 of Set 6 | takoradi
# Processing Record 49 of Set 6 | tagusao
# Processing Record 0 of Set 7 | adrar
# Processing Record 1 of Set 7 | lamu
# Processing Record 2 of Set 7 | severo-kurilsk
# Processing Record 3 of Set 7 | nioro
# Processing Record 4 of Set 7 | sao domingos do maranhao
# Processing Record 5 of Set 7 | yelniki
# Processing Record 6 of Set 7 | vao
# Processing Record 7 of Set 7 | zapolyarnyy
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | tutoia
# Processing Record 10 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 10 of Set 7 | tanjong tokong
# City not found. Skipping...
# Processing Record 10 of Set 7 | margaritas
# Processing Record 11 of Set 7 | dicabisagan
# Processing Record 12 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 7 | cherskiy
# Processing Record 13 of Set 7 | paita
# Processing Record 14 of Set 7 | padang
# Processing Record 15 of Set 7 | truth or consequences
# Processing Record 16 of Set 7 | krasnoselkup
# Processing Record 17 of Set 7 | richards bay
# Processing Record 18 of Set 7 | mehamn
# Processing Record 19 of Set 7 | abu samrah
# Processing Record 20 of Set 7 | selfoss
# Processing Record 21 of Set 7 | sao filipe
# Processing Record 22 of Set 7 | praia da vitoria
# Processing Record 23 of Set 7 | sambava
# Processing Record 24 of Set 7 | bontang
# Processing Record 25 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 7 | millington
# Processing Record 26 of Set 7 | isla mujeres
# Processing Record 27 of Set 7 | kyra
# Processing Record 28 of Set 7 | tabou
# Processing Record 29 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 7 | pisco
# Processing Record 30 of Set 7 | rassvet
# Processing Record 31 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 7 | upata
# Processing Record 32 of Set 7 | maceio
# Processing Record 33 of Set 7 | todos santos
# Processing Record 34 of Set 7 | lucapa
# Processing Record 35 of Set 7 | kualakapuas
# Processing Record 36 of Set 7 | wladyslawowo
# Processing Record 37 of Set 7 | sakakah
# Processing Record 38 of Set 7 | sayat
# Processing Record 39 of Set 7 | mongoumba
# Processing Record 40 of Set 7 | molo
# Processing Record 41 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 7 | vitim
# Processing Record 42 of Set 7 | grand gaube
# Processing Record 43 of Set 7 | solnechnyy
# Processing Record 44 of Set 7 | hasaki
# Processing Record 45 of Set 7 | king city
# Processing Record 46 of Set 7 | ileza
# Processing Record 47 of Set 7 | kupang
# Processing Record 48 of Set 7 | kidal
# Processing Record 49 of Set 7 | salme
# Processing Record 0 of Set 8 | sorland
# Processing Record 1 of Set 8 | pochutla
# Processing Record 2 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 2 of Set 8 | saint-joseph
# Processing Record 3 of Set 8 | karimganj
# Processing Record 4 of Set 8 | xining
# Processing Record 5 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 8 | ilhabela
# Processing Record 6 of Set 8 | ossora
# Processing Record 7 of Set 8 | lagoa
# Processing Record 8 of Set 8 | bulawayo
# Processing Record 9 of Set 8 | bonthe
# Processing Record 10 of Set 8 | probolinggo
# Processing Record 11 of Set 8 | shingu
# Processing Record 12 of Set 8 | cidreira
# Processing Record 13 of Set 8 | grand island
# Processing Record 14 of Set 8 | manthani
# Processing Record 15 of Set 8 | sept-iles
# Processing Record 16 of Set 8 | tidore
# City not found. Skipping...
# Processing Record
of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 9 | kupino
# Processing Record 0 of Set 10 | los alamos
# Processing Record 1 of Set 10 | temple
# Processing Record 2 of Set 10 | kommunisticheskiy
# Processing Record 3 of Set 10 | belmonte
# Processing Record 4 of Set 10 | flinders
# Processing Record 5 of Set 10 | mulege
# Processing Record 6 of Set 10 | kavaratti
# Processing Record 7 of Set 10 | seymchan
# Processing Record 8 of Set 10 | santa cruz de tenerife
# Processing Record 9 of Set 10 | taltal
# Processing Record 10 of Set 10 | buena vista
# Processing Record 11 of Set 10 | mehran
# Processing Record 12 of Set 10 | baft
# Processing Record 13 of Set 10 | trairi
# Processing Record 14 of Set 10 | val-david
# Processing Record 15 of Set 10 | yanji
# Processing Record 16 of Set 10 | norman wells
# Processing Record 17 of Set 10 | ponta delgada
# Processing Record 18 of Set 10 | yerbogachen
# Processing Record 19 of Set 10 | bereda
# Processing Record 20 of Set 10 | matadi
# Processing Record 21 of Set 10 | tarabuco
# Processing Record 22 of Set 10 | asau
# Processing Record 23 of Set 10 | luanda
# Processing Record 24 of Set 10 | nalut
# Processing Record 25 of Set 10 | maniitsoq
# Processing Record 26 of Set 10 | mananjary
# Processing Record 27 of Set 10 | mende
# Processing Record 28 of Set 10 | bow island
# Processing Record 29 of Set 10 | angoram
# Processing Record 30 of Set 10 | russkaya polyana
# Processing Record 31 of Set 10 | weinan
# Processing Record 32 of Set 10 | mocajuba
# Processing Record 33 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 10 | hambantota
# Processing Record 34 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 10 | valday
# Processing Record 35 of Set 10 | fort-shevchenko
# Processing Record 36 of Set 10 | mvuma
# Processing Record 37 of Set 10 | kalmunai
# Processing Record 38 of Set 10 | bacolod
# Processing Record 39 of Set 10 | hegang
# Processing Record 40 of Set 10 | port hardy
# Processing Record 41 of Set 10 | kalaleh
# Processing Record 42 of Set 10 | three hills
# Processing Record 43 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 10 | garm
# City not found. Skipping...
# Processing Record 43 of Set 10 | victoria point
# Processing Record 44 of Set 10 | bongandanga
# Processing Record 45 of Set 10 | shimoda
# Processing Record 46 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 46 of Set 10 | okha
# Processing Record 47 of Set 10 | maldonado
# Processing Record 48 of Set 10 | emba
# Processing Record 49 of Set 10 | falkoping
# City not found. Skipping...
# Processing Record 49 of Set 10 | mlyniv
# Processing Record 0 of Set 11 | bilibino
# Processing Record 1 of Set 11 | huntsville
# Processing Record 2 of Set 11 | santa maria
# Processing Record 3 of Set 11 | madang
# Processing Record 4 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 4 of Set 11 | lorengau
# Processing Record 5 of Set 11 | mafinga
# Processing Record 6 of Set 11 | shieli
# Processing Record 7 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 7 of Set 11 | muncar
# Processing Record 8 of Set 11 | mana
# Processing Record 9 of Set 11 | craig
# Processing Record 10 of Set 11 | tocopilla
# Processing Record 11 of Set 11 | ukiah
# Processing Record 12 of Set 11 | chit baragaon
# City not found. Skipping...
# Processing Record 12 of Set 11 | port macquarie
# Processing Record 13 of Set 11 | yulara
# Processing Record 14 of Set 11 | sakaiminato
# Processing Record 15 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 11 | vila do maio
# Processing Record 17 of Set 11 | sanok
# Processing Record 18 of Set 11 | nome
# Processing Record 19 of Set 11 | petauke
# Processing Record 20 of Set 11 | yenagoa
# Processing Record 21 of Set 11 | perth
# Processing Record 22 of Set 11 | taoudenni
# Processing Record 23 of Set 11 | ostrovnoy
# Processing Record 24 of Set 11 | araouane
# Processing Record 25 of Set 11 | waipawa
# Processing Record 26 of Set 11 | garowe
# Processing Record 27 of Set 11 | saint-francois
# Processing Record 28 of Set 11 | aitape
# Processing Record 29 of Set 11 | linxia
# Processing Record 30 of Set 11 | pangai
# Processing Record 31 of Set 11 | nyagan
# Processing Record 32 of Set 11 | itoman
# Processing Record 33 of Set 11 | krasnyy luch
# Processing Record 34 of Set 11 | pandan
# Processing Record 35 of Set 11 | mollendo
# Processing Record 36 of Set 11 | shelby
# Processing Record 37 of Set 11 | buraydah
# Processing Record 38 of Set 11 | merrill
# Processing Record 39 of Set 11 | steamboat springs
# Processing Record 40 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 11 | nantucket
# Processing Record 41 of Set 11 | ushtobe
# Processing Record 42 of Set 11 | lisakovsk
# Processing Record 43 of Set 11 | yeniseysk
# Processing Record 44 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 44 of Set 11 | serebryanyy bor
# Processing Record 45 of Set 11 | moyale
# Processing Record 46 of Set 11 | half moon bay
# Processing Record 47 of Set 11 | san pedro
# Processing Record 48 of Set 11 | anadyr
# Processing Record 49 of Set 11 | alice springs
# Processing Record 0 of Set 12 | constitucion
# Processing Record 1 of Set 12 | soc trang
# Processing Record 2 of Set 12 | key west
# Processing Record 3 of Set 12 | camabatela
# Processing Record 4 of Set 12 | burica
# City not found. Skipping...
# Processing Record 4 of Set 12 | kawakawa
# Processing Record 5 of Set 12 | vuktyl
# Processing Record 6 of Set 12 | kayerkan
# Processing Record 7 of Set 12 | khudumelapye
# Processing Record 8 of Set 12 | jibuti
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#BLEH I WANT TO SUCK YO' BLOOD BLEH
city_df = pd.DataFrame(city_datalist)

# Extract relevant fields from the data frame
file = open(output_data_file, 'w')
file.truncate()
file.close()

city_df.to_csv(output_data_file, index=False, header=True)
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        559 non-null    object
#  1   Lat         559 non-null    float64
#  2   Lng         559 non-null    float64
#  3   Max Temp    559 non-null    float64
#  4   Humidity    559 non-null    int64
#  5   Wind Speed  559 non-null    float64
#  6   Cloudiness  559 non-null    int64
#  7   Country     559 non-null    object
#  8   Date        559 non-null    int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 39.4+ KB

# %%
city_df
# Out:
#                City     Lat    Lng  Max Temp  Humidity  Wind Speed  \
# 0           Iqaluit  -68.51  63.75     55.40        87       16.11
# 1             Kapaa -159.32  22.08     82.40        74       10.29
# 2    Saint-Philippe   55.77 -21.36     62.60        63        6.93
# 3           Rikitea -134.97 -23.12     70.68        74        9.80
# 4       San Quintín -115.95  30.48     70.43        68       19.19
# ..              ...     ...    ...       ...       ...         ...
# 554        Kawakawa  174.07 -35.38     63.00         3        7.00
# 555          Vuktyl   57.31  63.86     59.86        82        9.08
# 556        Kayerkan   87.76  69.35     57.20        82        4.47
# 557    Khudumelapye   24.75 -23.88     52.18        38        6.13
# 558        Djibouti   42.50  11.50     89.60        62        3.36
#
#      Cloudiness Country        Date
# 0            90      CA  1596674195
# 1            90      US  1596674195
# 2            40      RE  1596673953
# 3            17      PF  1596673958
# 4             0      MX  1596674197
# ..          ...     ...         ...
# 554         100      NZ  1596674408
# 555          92      RU  1596674409
# 556           0      RU  1596674409
# 557           0      BW  1596674409
# 558          75      DJ  1596674410
#
# [559 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
high_humidity_count = len(city_df.loc[city_df['Humidity'] > 100])
print(f'There are {high_humidity_count} cities with humidity > 100%')
city_df.describe()
# Out:
# There are 0 cities with humidity > 100%
#               Lat         Lng    Max Temp    Humidity  Wind Speed  Cloudiness  \
# count  559.000000  559.000000  559.000000  559.000000  559.000000  559.000000
# mean    20.172952   21.011592   68.548962   69.776386    7.678301   46.892665
# std     90.659307   33.704530   13.125126   20.594700    4.747760   41.430331
# min   -175.200000  -54.800000   33.760000    3.000000    0.630000    0.000000
# 25%    -58.965000   -6.350000   59.020000   59.500000    4.160000    0.500000
# 50%     26.500000   25.690000   69.010000   74.000000    6.930000   40.000000
# 75%    100.345000   50.020000   78.910000   84.500000   10.290000   90.000000
# max    179.320000   78.220000  104.000000  100.000000   29.840000  100.000000
#
#                Date
# count  5.590000e+02
# mean   1.596674e+09
# std    9.038287e+01
# min    1.596674e+09
# 25%    1.596674e+09
# 50%    1.596674e+09
# 75%    1.596674e+09
# max    1.596674e+09

# %%
#  Get the indices of cities that have humidity over 100%.
high_humidity_cities = city_df.loc[city_df['Humidity'] > 100]
high_humidity_cities.index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_df = city_df.drop(index=high_humidity_cities.index, inplace=False)
clean_city_df
# Out:
#                City     Lat    Lng  Max Temp  Humidity  Wind Speed  \
# 0           Iqaluit  -68.51  63.75     55.40        87       16.11
# 1             Kapaa -159.32  22.08     82.40        74       10.29
# 2    Saint-Philippe   55.77 -21.36     62.60        63        6.93
# 3           Rikitea -134.97 -23.12     70.68        74        9.80
# 4       San Quintín -115.95  30.48     70.43        68       19.19
# ..              ...     ...    ...       ...       ...         ...
# 554        Kawakawa  174.07 -35.38     63.00         3        7.00
# 555          Vuktyl   57.31  63.86     59.86        82        9.08
# 556        Kayerkan   87.76  69.35     57.20        82        4.47
# 557    Khudumelapye   24.75 -23.88     52.18        38        6.13
# 558        Djibouti   42.50  11.50     89.60        62        3.36
#
#      Cloudiness Country        Date
# 0            90      CA  1596674195
# 1            90      US  1596674195
# 2            40      RE  1596673953
# 3            17      PF  1596673958
# 4             0      MX  1596674197
# ..          ...     ...         ...
# 554         100      NZ  1596674408
# 555          92      RU  1596674409
# 556           0      RU  1596674409
# 557           0      BW  1596674409
# 558          75      DJ  1596674410
#
# [559 rows x 9 columns]

# %%
# Extract relevant fields from the data frame
file = open(output_clean_data_file, 'w')
file.truncate()
file.close()

# Export the City_Data into a csv
clean_city_df.to_csv(output_clean_data_file, index=False, header=True)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_df = pd.read_csv(output_clean_data_file)

plot_lat = clean_city_df['Lat']
plot_temp = clean_city_df['Max Temp']
analysis_date = datetime.date.today().strftime('%m/%d/%Y')

lat_v_temp = plt.scatter(plot_lat, plot_temp, marker='o', facecolors='steelblue', edgecolors='black')
plt.title(f'City Latitude vs. Max Temperature ({analysis_date})')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plot_humidity = clean_city_df['Humidity']

lat_v_humidity = plt.scatter(plot_lat, plot_humidity, marker='o', facecolors='steelblue', edgecolors='black')

plt.title(f'City Latitude vs. Humidity ({analysis_date})')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plot_cloudiness = clean_city_df['Cloudiness']

lat_v_cloudiness = plt.scatter(plot_lat, plot_cloudiness, marker='o', facecolors='steelblue', edgecolors='black')

plt.title(f'City Latitude vs. Cloudiness ({analysis_date})')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plot_windspeed = clean_city_df['Wind Speed']

lat_v_windspeed = plt.scatter(plot_lat, plot_windspeed, marker='o', facecolors='steelblue', edgecolors='black')

plt.title(f'City Latitude vs. Wind Speed ({analysis_date})')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def lin_regress(x_values, x_label, y_values, y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = f'y = {str(round(slope, 2))}x + {str(round(intercept, 2))}'
    
    plt.scatter(x_values, y_values, marker='o', facecolors='steelblue', edgecolors='black')
    plt.plot(x_values, regress_values, 'r-')
    plt.annotate(line_eq,xy=(0.2,0.2),xycoords='figure fraction',fontsize=15,color="red")
    plt.title(f'{x_label} vs. {y_label} ({analysis_date})')
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    print(f'The r-squared is: {rvalue**2}')
    plt.grid()
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames

north_hemisphere_df = clean_city_df.loc[clean_city_df['Lat'] > 0]
south_hemisphere_df = clean_city_df.loc[clean_city_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_lat = north_hemisphere_df['Lat']
north_temp = north_hemisphere_df['Max Temp']

north_temp_v_lat = lin_regress(north_lat, f'{north_lat.name}itude', north_temp, north_temp.name)
# Out:
# The r-squared is: 0.005239178155014177

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_lat = south_hemisphere_df['Lat']
south_temp = south_hemisphere_df['Max Temp']

south_temp_v_lat = lin_regress(south_lat, f'{south_lat.name}itude', south_temp, south_temp.name)
# Out:
# The r-squared is: 0.03725228337113974

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_humidity = north_hemisphere_df['Humidity']

north_humidity_v_lat = lin_regress(north_lat, f'{north_lat.name}itude', north_humidity, north_humidity.name)
# Out:
# The r-squared is: 0.006997691222530711

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_humidity = south_hemisphere_df['Humidity']

south_humidity_v_lat = lin_regress(south_lat, f'{south_lat.name}itude', south_humidity, south_humidity.name)
# Out:
# The r-squared is: 0.10836273382858233

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_cloudiness = north_hemisphere_df['Cloudiness']

north_cloudiness_v_lat = lin_regress(north_lat, f'{north_lat.name}itude', north_cloudiness, north_cloudiness.name)
# Out:
# The r-squared is: 0.04993895300913035

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_cloudiness = south_hemisphere_df['Cloudiness']

south_cloudiness_v_lat = lin_regress(south_lat, f'{south_lat.name}itude', south_cloudiness, south_cloudiness.name)
# Out:
# The r-squared is: 0.001115893270710215

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_wind_speed = north_hemisphere_df['Wind Speed']

north_wind_speed_v_lat = lin_regress(north_lat, f'{north_lat.name}itude', north_wind_speed, north_wind_speed.name)
# Out:
# The r-squared is: 0.0031669473841420184

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_wind_speed = south_hemisphere_df['Wind Speed']

south_wind_speed_v_lat = lin_regress(south_lat, f'{south_lat.name}itude', south_wind_speed, south_wind_speed.name)
# Out:
# The r-squared is: 0.012202819169149236
